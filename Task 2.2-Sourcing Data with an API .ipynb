# %% [markdown]
# ## Exercise 2.2-Sourcing Data with API

# %% [markdown]
# ## Import and concatenate

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
from datetime import datetime

# %%
# Create a list with all files in the folder using a list comprehension

folderpath = r"C:\Users\Usha Bharati\OneDrive\Desktop\Citi Bike data\Citibike Dataset"
filepaths = [os.path.join(folderpath, name) for name in os.listdir(folderpath) if name.endswith('.csv')]

# %%
filepaths
# Out:
# ['C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202201-citibike-tripdata_1.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202201-citibike-tripdata_2.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202202-citibike-tripdata_1.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202202-citibike-tripdata_2.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202203-citibike-tripdata_1.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202203-citibike-tripdata_2.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202204-citibike-tripdata_1.csv',
#  'C:\\Users\\Usha Bharati\\OneDrive\\Desktop\\Citi Bike data\\Citibike Dataset\\202204-citibike-tripdata_2.csv',
# ...

# %%
df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
# Out:
# C:\Users\Usha Bharati\AppData\Local\Temp\ipykernel_16260\2545512019.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
# C:\Users\Usha Bharati\AppData\Local\Temp\ipykernel_16260\2545512019.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
# C:\Users\Usha Bharati\AppData\Local\Temp\ipykernel_16260\2545512019.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)
# C:\Users\Usha Bharati\AppData\Local\Temp\ipykernel_16260\2545512019.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# ## Comments given below describe how the code written to join the NewYork citi bikes data works.

# %% [markdown]
# ### Step 1- Creating a list of all files in the folder using list comprehension
# #### 1.In cell 2, a data folder has been created inside the working directory, and only the NewYork citi bikes data files in this folder have been stored.
# #### 2.This folder is stored in the string folderpath.
# #### 3.In the next step, the list filepaths containing the paths of all files in the folder Data is created using a list comprehension.
# #### 4.The 'os.listdir(folderpath)' is returning all files and directories in the folderpath directory.
# #### 5.'for name in os.listdir(folderpath)' loops through each name in the list returned by 'os.listdir(folderpath)'.
# #### 6.'os.path.join(folderpath, name)' is used to join the folderpath and name together to create a full file path.
# #### In summary,this code imports the necessary libraries and uses a list comprehension to create a list of file paths for all CSV files in the specified folder.

# %% [markdown]
# ### Step 2-Joining the datasets using 'Generator'
# #### In cell 4, we need to iterate through the files once, and generators are capable of handling one file at a time.
# ####  There is iteration of the list elements created in the step 1, where the function that’s applied iteratively is pd.read_csv().
# #### The read files are then passed into the pd.concat() function that returns the dataframe df.
# #### In summary, this code reads each CSV file into a DataFrame and concatenates them into a single DataFrame using pd.concat.

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df.shape
# Out:
# (30689921, 13)

# %% [markdown]
# #### Checking the head and tail of the data set combined with the shape shows us that all citi bikes data sets have been joined successfully.

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
df.tail()
# Out:
#                    ride_id  rideable_type           started_at  \
# 30689916  CB2EE50F60A58C7B   classic_bike  2022-12-12 08:38:46
# 30689917  3C0DF3280FEB1350   classic_bike  2022-12-12 13:06:32
# 30689918  B916E63B630D5020   classic_bike  2022-12-18 01:15:22
# 30689919  21EAC007BE7D4161   classic_bike  2022-12-08 23:09:54
# 30689920  538408C4A16F4415  electric_bike  2022-12-21 07:26:14
#
#                      ended_at                 start_station_name  \
# 30689916  2022-12-12 08:46:12  E 41 St & Madison Ave (SW corner)
# 30689917  2022-12-12 13:19:58               Peck Slip & South St
# 30689918  2022-12-18 01:48:15  E 41 St & Madison Ave (SW corner)
# 30689919  2022-12-08 23:26:37                   W 37 St & 10 Ave
# 30689920  2022-12-21 07:31:40                   W 37 St & 10 Ave
#
#          start_station_id         end_station_name end_station_id  start_lat  \
# 30689916          6474.12          6 Ave & W 33 St        6364.07  40.752165
# ...

# %% [markdown]
# ## Get weather data using NOAA's API

# %%
# Define your NOAA token - type yours in here! 

Token = 'kOHOifTHDTKOisgZVPZBYwNQDaprJJSq'

# %%
# Get the API 

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31',headers = {'token': Token})

# %%
# Load the api response as a json

d = json.loads(r.text)

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
# ...

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %% [markdown]
# ### Exporting weather data containing date and avgTemp to csv file

# %%
df_temp.to_csv('NYC_LaGuardia_Weather_2022.csv', index=False)

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
df['started_at'] = pd.to_datetime(df['started_at'], dayfirst = True)
# Out:
# C:\Users\Usha Bharati\AppData\Local\Temp\ipykernel_16260\1953011556.py:1: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['started_at'] = pd.to_datetime(df['started_at'], dayfirst = True)

# %%
df['date'] = pd.to_datetime(df['started_at'], format='%Y-%m-%d').dt.date

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %% [markdown]
# ### Merging weather data with New York CitiBike data set

# %%
# %%time
df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)
# Out:
# CPU times: total: 50 s
# Wall time: 1min 33s

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type          started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike 2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike 2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike 2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike 2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike 2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# ...

# %%
df_merged['_merge'].value_counts(dropna = False)
# Out:
# _merge
# both          30689921
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### Exporting merged dataset to a CSV file.

# %%
df_merged.to_csv('NewYork_Bikes_data.csv')

# %%
df.shape
# Out:
# (30689921, 14)
